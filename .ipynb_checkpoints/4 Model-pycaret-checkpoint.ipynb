# %%
import pandas as pd
from pycaret.classification import *

# %%
# Step 1: Load the cleaned dataset
df = pd.read_csv("Dataset/3 Balanced_Predictive_Maintenance.csv")

# Step 2: Initialize PyCaret setup (for PyCaret v3.x)
clf_setup = setup(
    data=df,
    target='Machine failure',
    ignore_features=['UDI', 'Product ID', 'Type', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF'],
    session_id=123,
    normalize=True,
    verbose=False  # Still okay to keep in v3
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 df = pd.read_csv("Dataset/3 Balanced_Predictive_Maintenance.csv")
#       4 # Step 2: Initialize PyCaret setup
# ----> 5 clf_setup = setup(
#       6     data=df,
#       7     target='Machine failure',
#       8     ignore_features=['UDI', 'Product ID', 'Type', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF'],
#       9     session_id=123,
#      10     normalize=True,
#      11     silent=False,         # Skips confirmation inputs
#      12     verbose=False        # Reduces logging
#      13 )
#
# TypeError: setup() got an unexpected keyword argument 'silent'

# %%
# Step 3: Compare models and select top 5
top_models = compare_models(n_select=5, sort='F1')
# Out:
# <style type="text/css">
# #T_fdde5 th {
#   text-align: left;
# }
# #T_fdde5_row0_col0, #T_fdde5_row1_col0, #T_fdde5_row1_col1, #T_fdde5_row1_col4, #T_fdde5_row1_col5, #T_fdde5_row1_col6, #T_fdde5_row1_col7, #T_fdde5_row2_col0, #T_fdde5_row2_col1, #T_fdde5_row2_col2, #T_fdde5_row2_col4, #T_fdde5_row2_col5, #T_fdde5_row2_col6, #T_fdde5_row2_col7, #T_fdde5_row3_col0, #T_fdde5_row3_col1, #T_fdde5_row3_col2, #T_fdde5_row3_col4, #T_fdde5_row3_col5, #T_fdde5_row3_col6, #T_fdde5_row3_col7, #T_fdde5_row4_col0, #T_fdde5_row4_col1, #T_fdde5_row4_col2, #T_fdde5_row4_col4, #T_fdde5_row4_col5, #T_fdde5_row4_col6, #T_fdde5_row4_col7, #T_fdde5_row5_col0, #T_fdde5_row5_col1, #T_fdde5_row5_col2, #T_fdde5_row5_col3, #T_fdde5_row5_col4, #T_fdde5_row5_col5, #T_fdde5_row5_col6, #T_fdde5_row5_col7, #T_fdde5_row6_col0, #T_fdde5_row6_col1, #T_fdde5_row6_col2, #T_fdde5_row6_col3, #T_fdde5_row6_col4, #T_fdde5_row6_col5, #T_fdde5_row6_col6, #T_fdde5_row6_col7, #T_fdde5_row7_col0, #T_fdde5_row7_col1, #T_fdde5_row7_col2, #T_fdde5_row7_col3, #T_fdde5_row7_col4, #T_fdde5_row7_col5, #T_fdde5_row7_col6, #T_fdde5_row7_col7, #T_fdde5_row8_col0, #T_fdde5_row8_col1, #T_fdde5_row8_col2, #T_fdde5_row8_col3, #T_fdde5_row8_col4, #T_fdde5_row8_col5, #T_fdde5_row8_col6, #T_fdde5_row8_col7, #T_fdde5_row9_col0, #T_fdde5_row9_col1, #T_fdde5_row9_col2, #T_fdde5_row9_col3, #T_fdde5_row9_col4, #T_fdde5_row9_col5, #T_fdde5_row9_col6, #T_fdde5_row9_col7, #T_fdde5_row10_col0, #T_fdde5_row10_col1, #T_fdde5_row10_col2, #T_fdde5_row10_col3, #T_fdde5_row10_col4, #T_fdde5_row10_col5, #T_fdde5_row10_col6, #T_fdde5_row10_col7, #T_fdde5_row11_col0, #T_fdde5_row11_col1, #T_fdde5_row11_col2, #T_fdde5_row11_col3, #T_fdde5_row11_col4, #T_fdde5_row11_col5, #T_fdde5_row11_col6, #T_fdde5_row11_col7, #T_fdde5_row12_col0, #T_fdde5_row12_col1, #T_fdde5_row12_col2, #T_fdde5_row12_col3, #T_fdde5_row12_col4, #T_fdde5_row12_col5, #T_fdde5_row12_col6, #T_fdde5_row12_col7, #T_fdde5_row13_col0, #T_fdde5_row13_col1, #T_fdde5_row13_col2, #T_fdde5_row13_col3, #T_fdde5_row13_col4, #T_fdde5_row13_col5, #T_fdde5_row13_col6, #T_fdde5_row13_col7 {
#   text-align: left;
# }
# #T_fdde5_row0_col1, #T_fdde5_row0_col2, #T_fdde5_row0_col3, #T_fdde5_row0_col4, #T_fdde5_row0_col5, #T_fdde5_row0_col6, #T_fdde5_row0_col7, #T_fdde5_row1_col2, #T_fdde5_row1_col3, #T_fdde5_row2_col3, #T_fdde5_row3_col3, #T_fdde5_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fdde5_row0_col8, #T_fdde5_row1_col8, #T_fdde5_row2_col8, #T_fdde5_row3_col8, #T_fdde5_row4_col8, #T_fdde5_row5_col8, #T_fdde5_row6_col8, #T_fdde5_row7_col8, #T_fdde5_row8_col8, #T_fdde5_row9_col8, #T_fdde5_row10_col8, #T_fdde5_row11_col8, #T_fdde5_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fdde5_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fdde5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdde5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fdde5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fdde5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fdde5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fdde5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fdde5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fdde5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fdde5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fdde5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdde5_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_fdde5_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_fdde5_row0_col1" class="data row0 col1" >0.9982</td>
#       <td id="T_fdde5_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_fdde5_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_fdde5_row0_col4" class="data row0 col4" >0.9963</td>
#       <td id="T_fdde5_row0_col5" class="data row0 col5" >0.9982</td>
#       <td id="T_fdde5_row0_col6" class="data row0 col6" >0.9963</td>
#       <td id="T_fdde5_row0_col7" class="data row0 col7" >0.9963</td>
#       <td id="T_fdde5_row0_col8" class="data row0 col8" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_fdde5_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_fdde5_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_fdde5_row1_col1" class="data row1 col1" >0.9947</td>
#       <td id="T_fdde5_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_fdde5_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_fdde5_row1_col4" class="data row1 col4" >0.9895</td>
#       <td id="T_fdde5_row1_col5" class="data row1 col5" >0.9947</td>
#       <td id="T_fdde5_row1_col6" class="data row1 col6" >0.9894</td>
#       <td id="T_fdde5_row1_col7" class="data row1 col7" >0.9894</td>
#       <td id="T_fdde5_row1_col8" class="data row1 col8" >0.3250</td>
#     </tr>
#     <tr>
#       <th id="T_fdde5_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_fdde5_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_fdde5_row2_col1" class="data row2 col1" >0.9928</td>
#       <td id="T_fdde5_row2_col2" class="data row2 col2" >0.9928</td>
#       <td id="T_fdde5_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_fdde5_row2_col4" class="data row2 col4" >0.9859</td>
#       <td id="T_fdde5_row2_col5" class="data row2 col5" >0.9929</td>
#       <td id="T_fdde5_row2_col6" class="data row2 col6" >0.9857</td>
#       <td id="T_fdde5_row2_col7" class="data row2 col7" >0.9858</td>
#       <td id="T_fdde5_row2_col8" class="data row2 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_fdde5_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_fdde5_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fdde5_row3_col1" class="data row3 col1" >0.9917</td>
#       <td id="T_fdde5_row3_col2" class="data row3 col2" >0.9995</td>
#       <td id="T_fdde5_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_fdde5_row3_col4" class="data row3 col4" >0.9838</td>
#       <td id="T_fdde5_row3_col5" class="data row3 col5" >0.9918</td>
#       <td id="T_fdde5_row3_col6" class="data row3 col6" >0.9834</td>
#       <td id="T_fdde5_row3_col7" class="data row3 col7" >0.9836</td>
#       <td id="T_fdde5_row3_col8" class="data row3 col8" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_fdde5_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_fdde5_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_fdde5_row4_col1" class="data row4 col1" >0.9740</td>
#       <td id="T_fdde5_row4_col2" class="data row4 col2" >0.9905</td>
#       <td id="T_fdde5_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_fdde5_row4_col4" class="data row4 col4" >0.9506</td>
#       <td id="T_fdde5_row4_col5" class="data row4 col5" >0.9747</td>
#       <td id="T_fdde5_row4_col6" class="data row4 col6" >0.9479</td>
#       <td id="T_fdde5_row4_col7" class="data row4 col7" >0.9493</td>
#       <td id="T_fdde5_row4_col8" class="data row4 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_fdde5_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_fdde5_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_fdde5_row5_col1" class="data row5 col1" >0.9575</td>
#       <td id="T_fdde5_row5_col2" class="data row5 col2" >0.9895</td>
#       <td id="T_fdde5_row5_col3" class="data row5 col3" >0.9789</td>
#       <td id="T_fdde5_row5_col4" class="data row5 col4" >0.9388</td>
#       <td id="T_fdde5_row5_col5" class="data row5 col5" >0.9584</td>
#       <td id="T_fdde5_row5_col6" class="data row5 col6" >0.9150</td>
#       <td id="T_fdde5_row5_col7" class="data row5 col7" >0.9158</td>

# %%
# Step 4: Tune each of the top models
tuned_models = [tune_model(model, optimize='F1') for model in top_models]
# Out:
# <style type="text/css">
# #T_3376e th {
#   text-align: left;
# }
# #T_3376e_row0_col0, #T_3376e_row1_col0, #T_3376e_row1_col1, #T_3376e_row1_col4, #T_3376e_row1_col5, #T_3376e_row1_col6, #T_3376e_row1_col7, #T_3376e_row2_col0, #T_3376e_row2_col1, #T_3376e_row2_col2, #T_3376e_row2_col4, #T_3376e_row2_col5, #T_3376e_row2_col6, #T_3376e_row2_col7, #T_3376e_row3_col0, #T_3376e_row3_col1, #T_3376e_row3_col2, #T_3376e_row3_col4, #T_3376e_row3_col5, #T_3376e_row3_col6, #T_3376e_row3_col7, #T_3376e_row4_col0, #T_3376e_row4_col1, #T_3376e_row4_col2, #T_3376e_row4_col4, #T_3376e_row4_col5, #T_3376e_row4_col6, #T_3376e_row4_col7, #T_3376e_row5_col0, #T_3376e_row5_col1, #T_3376e_row5_col2, #T_3376e_row5_col3, #T_3376e_row5_col4, #T_3376e_row5_col5, #T_3376e_row5_col6, #T_3376e_row5_col7, #T_3376e_row6_col0, #T_3376e_row6_col1, #T_3376e_row6_col2, #T_3376e_row6_col3, #T_3376e_row6_col4, #T_3376e_row6_col5, #T_3376e_row6_col6, #T_3376e_row6_col7, #T_3376e_row7_col0, #T_3376e_row7_col1, #T_3376e_row7_col2, #T_3376e_row7_col3, #T_3376e_row7_col4, #T_3376e_row7_col5, #T_3376e_row7_col6, #T_3376e_row7_col7, #T_3376e_row8_col0, #T_3376e_row8_col1, #T_3376e_row8_col2, #T_3376e_row8_col3, #T_3376e_row8_col4, #T_3376e_row8_col5, #T_3376e_row8_col6, #T_3376e_row8_col7, #T_3376e_row9_col0, #T_3376e_row9_col1, #T_3376e_row9_col2, #T_3376e_row9_col3, #T_3376e_row9_col4, #T_3376e_row9_col5, #T_3376e_row9_col6, #T_3376e_row9_col7, #T_3376e_row10_col0, #T_3376e_row10_col1, #T_3376e_row10_col2, #T_3376e_row10_col3, #T_3376e_row10_col4, #T_3376e_row10_col5, #T_3376e_row10_col6, #T_3376e_row10_col7, #T_3376e_row11_col0, #T_3376e_row11_col1, #T_3376e_row11_col2, #T_3376e_row11_col3, #T_3376e_row11_col4, #T_3376e_row11_col5, #T_3376e_row11_col6, #T_3376e_row11_col7, #T_3376e_row12_col0, #T_3376e_row12_col1, #T_3376e_row12_col2, #T_3376e_row12_col3, #T_3376e_row12_col4, #T_3376e_row12_col5, #T_3376e_row12_col6, #T_3376e_row12_col7, #T_3376e_row13_col0, #T_3376e_row13_col1, #T_3376e_row13_col2, #T_3376e_row13_col3, #T_3376e_row13_col4, #T_3376e_row13_col5, #T_3376e_row13_col6, #T_3376e_row13_col7 {
#   text-align: left;
# }
# #T_3376e_row0_col1, #T_3376e_row0_col2, #T_3376e_row0_col3, #T_3376e_row0_col4, #T_3376e_row0_col5, #T_3376e_row0_col6, #T_3376e_row0_col7, #T_3376e_row1_col2, #T_3376e_row1_col3, #T_3376e_row2_col3, #T_3376e_row3_col3, #T_3376e_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3376e_row0_col8, #T_3376e_row1_col8, #T_3376e_row2_col8, #T_3376e_row3_col8, #T_3376e_row4_col8, #T_3376e_row5_col8, #T_3376e_row6_col8, #T_3376e_row8_col8, #T_3376e_row9_col8, #T_3376e_row10_col8, #T_3376e_row11_col8, #T_3376e_row12_col8, #T_3376e_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3376e_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3376e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3376e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3376e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3376e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3376e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3376e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3376e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3376e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3376e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3376e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3376e_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_3376e_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_3376e_row0_col1" class="data row0 col1" >0.9982</td>
#       <td id="T_3376e_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_3376e_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_3376e_row0_col4" class="data row0 col4" >0.9963</td>
#       <td id="T_3376e_row0_col5" class="data row0 col5" >0.9982</td>
#       <td id="T_3376e_row0_col6" class="data row0 col6" >0.9963</td>
#       <td id="T_3376e_row0_col7" class="data row0 col7" >0.9963</td>
#       <td id="T_3376e_row0_col8" class="data row0 col8" >0.1950</td>
#     </tr>
#     <tr>
#       <th id="T_3376e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_3376e_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_3376e_row1_col1" class="data row1 col1" >0.9947</td>
#       <td id="T_3376e_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_3376e_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_3376e_row1_col4" class="data row1 col4" >0.9895</td>
#       <td id="T_3376e_row1_col5" class="data row1 col5" >0.9947</td>
#       <td id="T_3376e_row1_col6" class="data row1 col6" >0.9894</td>
#       <td id="T_3376e_row1_col7" class="data row1 col7" >0.9894</td>
#       <td id="T_3376e_row1_col8" class="data row1 col8" >0.3250</td>
#     </tr>
#     <tr>
#       <th id="T_3376e_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_3376e_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_3376e_row2_col1" class="data row2 col1" >0.9928</td>
#       <td id="T_3376e_row2_col2" class="data row2 col2" >0.9928</td>
#       <td id="T_3376e_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_3376e_row2_col4" class="data row2 col4" >0.9859</td>
#       <td id="T_3376e_row2_col5" class="data row2 col5" >0.9929</td>
#       <td id="T_3376e_row2_col6" class="data row2 col6" >0.9857</td>
#       <td id="T_3376e_row2_col7" class="data row2 col7" >0.9858</td>
#       <td id="T_3376e_row2_col8" class="data row2 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_3376e_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_3376e_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3376e_row3_col1" class="data row3 col1" >0.9917</td>
#       <td id="T_3376e_row3_col2" class="data row3 col2" >0.9995</td>
#       <td id="T_3376e_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_3376e_row3_col4" class="data row3 col4" >0.9838</td>
#       <td id="T_3376e_row3_col5" class="data row3 col5" >0.9918</td>
#       <td id="T_3376e_row3_col6" class="data row3 col6" >0.9834</td>
#       <td id="T_3376e_row3_col7" class="data row3 col7" >0.9836</td>
#       <td id="T_3376e_row3_col8" class="data row3 col8" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_3376e_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_3376e_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_3376e_row4_col1" class="data row4 col1" >0.9740</td>
#       <td id="T_3376e_row4_col2" class="data row4 col2" >0.9905</td>
#       <td id="T_3376e_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_3376e_row4_col4" class="data row4 col4" >0.9506</td>
#       <td id="T_3376e_row4_col5" class="data row4 col5" >0.9747</td>
#       <td id="T_3376e_row4_col6" class="data row4 col6" >0.9479</td>
#       <td id="T_3376e_row4_col7" class="data row4 col7" >0.9493</td>
#       <td id="T_3376e_row4_col8" class="data row4 col8" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_3376e_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_3376e_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3376e_row5_col1" class="data row5 col1" >0.9575</td>
#       <td id="T_3376e_row5_col2" class="data row5 col2" >0.9895</td>
#       <td id="T_3376e_row5_col3" class="data row5 col3" >0.9789</td>
#       <td id="T_3376e_row5_col4" class="data row5 col4" >0.9388</td>
#       <td id="T_3376e_row5_col5" class="data row5 col5" >0.9584</td>
#       <td id="T_3376e_row5_col6" class="data row5 col6" >0.9150</td>
#       <td id="T_3376e_row5_col7" class="data row5 col7" >0.9158</td>

# %%
# Step 5: Compare only the tuned models
best_tuned_model = compare_models(models=tuned_models, sort='F1')

# %%
# Step 6: Finalize the best tuned model
final_model = finalize_model(best_tuned_model)

# %%
# Step 7: Evaluate the final model
evaluate_model(final_model)
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Air temperature [K]',
#                                               'Process temperature [K]',
#                                               'Rotational speed [rpm]',
#                                               'Torque [Nm]', 'Tool wear [min]'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categori...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=123, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'best_machine_failure_model.pkl')

# %%
save_model(final_model, 'best_machine_failure_model')
